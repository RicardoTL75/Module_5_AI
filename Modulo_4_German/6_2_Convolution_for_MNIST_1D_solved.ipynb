# %% [markdown]
# # **Convolución para MNIST-1D**
#
# Este cuaderno explora una red convolucional 1D para MNIST-1D.
#
# Ejecuta las celdas en orden. En varios lugares verás la palabra "TAREA": sigue esas instrucciones, anticipa qué ocurrirá o escribe el código necesario para completar las funciones.

# %%
# Ejecuta esta celda una vez si necesitas instalar el repositorio MNIST-1D
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-wz36mm60
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-wz36mm60
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=15945 sha256=1accf941b62c6944c9aebf57c88b5775e83b03e1eef13b00b9963191f07f4147
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sfq8bnw5/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# Las entradas y salidas de entrenamiento y prueba están en
# data['x'], data['y'], data['x_test'] y data['y_test']
print("Samples in training set: {}".format(len(data['y'])))
print("Samples in test set: {}".format(len(data['y_test'])))
print("Length of each sample: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Samples in training set: 4000
# Samples in test set: 1000
# Length of each sample: 40

# %%
# Carga los datos
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Muestra los tamaños
print("Training data: %d samples (columns), each with %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d samples (columns), each with %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Training data: 4000 samples (columns), each with 40 dimensions (rows)
# Validation data: 1000 samples (columns), each with 40 dimensions (rows)

# %% [markdown]
# Define la red

# %%
# Estos datos tienen 40 dimensiones de entrada y 10 dimensiones de salida
# Las entradas corresponden a los 40 desplazamientos de la plantilla MNIST-1D.
D_i = 40
# Las salidas corresponden a los 10 dígitos
D_o = 10


# TAREA: crea un modelo con las siguientes capas
# 1. Capa convolucional (entrada: longitud 40 y 1 canal; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 2. ReLU
# 3. Capa convolucional (entrada: longitud 19 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 4. ReLU
# 5. Capa convolucional (entrada: longitud 9 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 6. ReLU
# 7. Aplanamiento (convierte 4x15) a longitud 60
# 8. Capa lineal (tamaño de entrada = 60, tamaño de salida = 10)
# Documentación útil:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# TEN EN CUENTA QUE LAS CAPAS CONVOLUCIONALES NECESITAN RECIBIR EL NÚMERO DE CANALES DE ENTRADA COMO PARÁMETRO
# Y NO EL TAMAÑO DE LA ENTRADA.

# Reemplaza la siguiente función:
model = nn.Sequential(
    # 1. Convolución: 1 canal de entrada -> 15 canales de salida
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    # 2. Convolución: 15 -> 15 canales
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    # 3. Convolución: 15 -> 15 canales
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    # 4. Aplanamiento (15 × 4 = 60)
    nn.Flatten(),

    # 5. Capa totalmente conectada
    nn.Linear(60, 10)
)

# %%
# Inicialización de pesos de He
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# Elige la función de pérdida de entropía cruzada
loss_function = nn.CrossEntropyLoss()
# Construye el optimizador SGD e inicializa la tasa de aprendizaje y el momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# Objeto que reduce la tasa de aprendizaje a la mitad cada 20 épocas
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# Crea los tensores de datos y guárdalos en un DataLoader
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# Carga los datos en una clase que crea los lotes
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Inicializa los pesos del modelo
model.apply(weights_init)

# Recorre el conjunto de datos n_epoch veces
n_epoch = 100
# Guarda la pérdida y el porcentaje de error en cada época
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # Recorre los lotes
  for i, data in enumerate(data_loader):
    # Recupera entradas y etiquetas de este lote
    x_batch, y_batch = data
    # Reinicia los gradientes de los parámetros
    optimizer.zero_grad()
    # Paso hacia adelante: calcula la salida del modelo
    pred = model(x_batch[:,None,:])
    # Calcula la pérdida
    loss = loss_function(pred, y_batch)
    # Paso hacia atrás
    loss.backward()
    # Actualización SGD
    optimizer.step()

  # Ejecuta todo el conjunto de datos para obtener estadísticas; normalmente no harías esto
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, training loss {losses_train[epoch]:.6f}, training error {errors_train[epoch]:3.2f}, validation loss {losses_val[epoch]:.6f}, validation error {errors_val[epoch]:3.2f}')

  # Indica al programador que evalúe si debe actualizar la tasa de aprendizaje
  scheduler.step()

# Grafica los resultados
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='entrenamiento')
ax.plot(errors_val,'b-',label='validación')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.legend()
plt.show()
# Out:
# Epoch     0, training loss 2.210756, training error 80.65, validation loss 2.215805, validation error 79.50
# Epoch     1, training loss 1.809733, training error 70.80, validation loss 1.816069, validation error 73.70
# Epoch     2, training loss 1.434449, training error 57.45, validation loss 1.449607, validation error 59.70
# Epoch     3, training loss 1.362495, training error 56.97, validation loss 1.374058, validation error 59.80
# Epoch     4, training loss 1.280407, training error 52.50, validation loss 1.285412, validation error 54.40
# Epoch     5, training loss 1.122501, training error 45.28, validation loss 1.152734, validation error 49.70
# Epoch     6, training loss 1.129151, training error 44.28, validation loss 1.188405, validation error 46.90
# Epoch     7, training loss 0.928504, training error 37.70, validation loss 0.982251, validation error 40.30
# Epoch     8, training loss 0.852574, training error 34.47, validation loss 0.895623, validation error 37.20
# Epoch     9, training loss 0.949076, training error 37.40, validation loss 1.011812, validation error 40.90
# Epoch    10, training loss 0.742419, training error 29.60, validation loss 0.804685, validation error 33.20
# Epoch    11, training loss 0.756431, training error 30.50, validation loss 0.830386, validation error 32.30
# Epoch    12, training loss 0.602706, training error 22.97, validation loss 0.670270, validation error 26.60
# Epoch    13, training loss 0.579059, training error 22.40, validation loss 0.675236, validation error 26.90
# Epoch    14, training loss 0.519557, training error 19.50, validation loss 0.606124, validation error 24.40
# Epoch    15, training loss 0.521642, training error 21.05, validation loss 0.613385, validation error 24.20
# Epoch    16, training loss 0.431785, training error 16.38, validation loss 0.545150, validation error 21.20
# Epoch    17, training loss 0.370364, training error 13.60, validation loss 0.523398, validation error 19.50
# Epoch    18, training loss 0.339126, training error 12.10, validation loss 0.463699, validation error 15.80
# Epoch    19, training loss 0.261158, training error 9.32, validation loss 0.399038, validation error 14.30
# Epoch    20, training loss 0.224370, training error 7.55, validation loss 0.376626, validation error 13.40
# Epoch    21, training loss 0.202862, training error 6.53, validation loss 0.352124, validation error 12.20
# Epoch    22, training loss 0.196560, training error 6.43, validation loss 0.353923, validation error 11.20
# Epoch    23, training loss 0.186235, training error 6.15, validation loss 0.353506, validation error 11.20
# Epoch    24, training loss 0.161822, training error 5.00, validation loss 0.353268, validation error 10.60
# Epoch    25, training loss 0.153125, training error 4.97, validation loss 0.326583, validation error 10.40
# Epoch    26, training loss 0.150346, training error 4.72, validation loss 0.354348, validation error 11.40
# Epoch    27, training loss 0.131422, training error 3.68, validation loss 0.348320, validation error 10.10
# Epoch    28, training loss 0.155497, training error 5.32, validation loss 0.383290, validation error 11.20
# Epoch    29, training loss 0.134564, training error 4.43, validation loss 0.362442, validation error 10.10
# Epoch    30, training loss 0.123035, training error 3.75, validation loss 0.335878, validation error 10.10
# Epoch    31, training loss 0.124864, training error 4.12, validation loss 0.346625, validation error 11.30
# Epoch    32, training loss 0.132111, training error 4.72, validation loss 0.355648, validation error 10.80
# Epoch    33, training loss 0.099711, training error 3.00, validation loss 0.328706, validation error 9.70
# Epoch    34, training loss 0.110325, training error 3.65, validation loss 0.357464, validation error 9.00
# Epoch    35, training loss 0.089743, training error 2.60, validation loss 0.334903, validation error 9.00
# Epoch    36, training loss 0.085559, training error 2.50, validation loss 0.322572, validation error 8.90
# Epoch    37, training loss 0.078130, training error 2.45, validation loss 0.343889, validation error 9.10
# Epoch    38, training loss 0.072301, training error 1.82, validation loss 0.319572, validation error 8.90
# Epoch    39, training loss 0.070339, training error 2.05, validation loss 0.353997, validation error 8.20
# Epoch    40, training loss 0.062350, training error 1.50, validation loss 0.327588, validation error 8.40
# Epoch    41, training loss 0.059555, training error 1.47, validation loss 0.330082, validation error 8.30
# Epoch    42, training loss 0.063615, training error 1.90, validation loss 0.328616, validation error 8.30
# Epoch    43, training loss 0.056030, training error 1.22, validation loss 0.336905, validation error 8.60
# Epoch    44, training loss 0.056492, training error 1.25, validation loss 0.337474, validation error 8.80
# Epoch    45, training loss 0.058095, training error 1.55, validation loss 0.335149, validation error 8.60
# Epoch    46, training loss 0.055409, training error 1.40, validation loss 0.342945, validation error 8.60
# Epoch    47, training loss 0.059903, training error 1.88, validation loss 0.365900, validation error 8.50
# Epoch    48, training loss 0.053528, training error 1.28, validation loss 0.343364, validation error 8.70
# Epoch    49, training loss 0.055348, training error 1.38, validation loss 0.363171, validation error 9.10
# Epoch    50, training loss 0.047142, training error 0.93, validation loss 0.349480, validation error 8.40
# Epoch    51, training loss 0.052713, training error 1.53, validation loss 0.370356, validation error 8.50
# Epoch    52, training loss 0.046005, training error 1.07, validation loss 0.347485, validation error 8.30
# Epoch    53, training loss 0.044490, training error 0.97, validation loss 0.352546, validation error 8.40
# Epoch    54, training loss 0.044204, training error 1.00, validation loss 0.351357, validation error 8.50
# Epoch    55, training loss 0.043837, training error 0.97, validation loss 0.355887, validation error 8.60
# Epoch    56, training loss 0.045779, training error 1.20, validation loss 0.359368, validation error 8.30
# Epoch    57, training loss 0.044896, training error 1.20, validation loss 0.359589, validation error 8.40
# Epoch    58, training loss 0.041772, training error 1.03, validation loss 0.364038, validation error 8.40
# Epoch    59, training loss 0.041530, training error 0.85, validation loss 0.362945, validation error 8.30
# Epoch    60, training loss 0.037683, training error 0.75, validation loss 0.358569, validation error 8.20
# Epoch    61, training loss 0.037677, training error 0.75, validation loss 0.368765, validation error 8.20
# Epoch    62, training loss 0.036123, training error 0.68, validation loss 0.360071, validation error 8.40
# Epoch    63, training loss 0.036159, training error 0.62, validation loss 0.359250, validation error 8.70
# Epoch    64, training loss 0.035318, training error 0.57, validation loss 0.364598, validation error 8.50
# Epoch    65, training loss 0.034774, training error 0.62, validation loss 0.369382, validation error 8.30
# Epoch    66, training loss 0.034304, training error 0.55, validation loss 0.361212, validation error 8.10
# Epoch    67, training loss 0.033807, training error 0.62, validation loss 0.362637, validation error 8.40
# Epoch    68, training loss 0.034595, training error 0.55, validation loss 0.377531, validation error 8.30
# Epoch    69, training loss 0.035261, training error 0.75, validation loss 0.363807, validation error 8.20
# Epoch    70, training loss 0.033277, training error 0.65, validation loss 0.366608, validation error 8.20
# Epoch    71, training loss 0.032594, training error 0.55, validation loss 0.370048, validation error 8.30
# Epoch    72, training loss 0.032212, training error 0.55, validation loss 0.374055, validation error 8.00
# Epoch    73, training loss 0.031472, training error 0.47, validation loss 0.375099, validation error 8.00
# Epoch    74, training loss 0.032165, training error 0.55, validation loss 0.381248, validation error 8.20
# Epoch    75, training loss 0.030823, training error 0.50, validation loss 0.375285, validation error 8.20
# Epoch    76, training loss 0.031197, training error 0.47, validation loss 0.376004, validation error 8.20
# Epoch    77, training loss 0.030157, training error 0.47, validation loss 0.373678, validation error 8.30
# Epoch    78, training loss 0.029637, training error 0.45, validation loss 0.378269, validation error 8.30
# Epoch    79, training loss 0.029512, training error 0.45, validation loss 0.382575, validation error 8.20
# Epoch    80, training loss 0.029043, training error 0.40, validation loss 0.380508, validation error 8.10
# Epoch    81, training loss 0.029003, training error 0.40, validation loss 0.379750, validation error 8.00
# Epoch    82, training loss 0.028558, training error 0.43, validation loss 0.378825, validation error 8.10
# Epoch    83, training loss 0.028485, training error 0.43, validation loss 0.377517, validation error 8.10
# Epoch    84, training loss 0.028570, training error 0.43, validation loss 0.378491, validation error 8.10
# Epoch    85, training loss 0.028373, training error 0.43, validation loss 0.382885, validation error 8.20
# Epoch    86, training loss 0.028432, training error 0.40, validation loss 0.384210, validation error 7.90
# Epoch    87, training loss 0.028150, training error 0.43, validation loss 0.385417, validation error 8.00
# Epoch    88, training loss 0.027876, training error 0.45, validation loss 0.380379, validation error 8.30
# Epoch    89, training loss 0.028061, training error 0.45, validation loss 0.385883, validation error 8.20
# Epoch    90, training loss 0.027362, training error 0.38, validation loss 0.384026, validation error 8.20
# Epoch    91, training loss 0.027416, training error 0.45, validation loss 0.381590, validation error 8.10
# Epoch    92, training loss 0.027037, training error 0.40, validation loss 0.381528, validation error 8.00
# Epoch    93, training loss 0.027334, training error 0.45, validation loss 0.380875, validation error 7.90
# Epoch    94, training loss 0.026689, training error 0.38, validation loss 0.384629, validation error 8.10
# Epoch    95, training loss 0.026961, training error 0.47, validation loss 0.383969, validation error 8.30
# Epoch    96, training loss 0.026573, training error 0.40, validation loss 0.384510, validation error 8.20
# Epoch    97, training loss 0.026300, training error 0.38, validation loss 0.387295, validation error 8.00
# Epoch    98, training loss 0.026144, training error 0.38, validation loss 0.386894, validation error 8.10
# Epoch    99, training loss 0.026118, training error 0.38, validation loss 0.390052, validation error 8.10
